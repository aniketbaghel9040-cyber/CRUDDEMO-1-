# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketbaghel9040-cyber/CRUDDEMO-1-/blob/main/NLP(nltk).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import urllib.request

try:
    print(urllib.request.urlopen("https://www.google.com").status)
except Exception as e:
    print(e)
# Out:
# 200

# %%
from nltk.tokenize import word_tokenize

text = "Hello! My name is Aniket. I am learning NLP."

tokens = word_tokenize(text)

print(tokens)
# Out:
# ['Hello', '!', 'My', 'name', 'is', 'Aniket', '.', 'I', 'am', 'learning', 'NLP', '.']
